# %% [markdown]
# # Lab 4: Point Pattern Analysis
#
# #### In this lab, you will practise to use influential statistical methods to analyze point patterns.
#
# #### Specifically, the following methods will be used.
#
# - Nearest Neighbor Distance
# - Reply's K-function
#
# Before the lab, please download the data from [here]()

# %% [markdown]
# ## 1. Read and process data

# %% [markdown]
# Read required packages for this lab

# %%
import pandas as pd
import matplotlib.pyplot as plt

import scipy.spatial
import libpysal as ps
import numpy as np
from pointpats import PointPattern,PoissonPointProcess, as_window, G, F, J, K, L, Genv, Fenv, Jenv, Kenv, Lenv

# %% [markdown]
# Change path of PROJ_LIB and import basemap.
# You can copy the path from your work in Lab 3.

# %%
import os
# You need to replace the path with the folder of Anaconda in your computer
os.environ['PROJ_LIB'] = 'C:/ProgramData/Anaconda3/Library/share/'

from mpl_toolkits.basemap import Basemap

# %% [markdown]
# Read the chicago supermarkets as a data frame

# %%
df = pd.read_csv("C:/Users/yi/Documents/UH_work/Teaching/GEOG389/labs/lab4_data/chicago_stores.csv")

# %% [markdown]
# Preview data

# %%
df.head()
# Out:
#                  STORE NAME  LICENSE ID  ACCOUNT NUMBER  SQUARE FEET  \
# 0               200 LIQUORS     48663.0         17055.0       5000.0
# 1           3600 COMMISSARY     24279.0          9830.0       3800.0
# 2   4343 PETES FRESH MARKET   1336669.0        260303.0      57000.0
# 3  4700 PETE'S FRESH MARKET   1243125.0        245519.0      45000.0
# 4          5659 W. DIVERSEY   1575023.0        277375.0       4000.0
#
#   BUFFER SIZE               ADDRESS  ZIP CODE COMMUNITY AREA NAME  \
# 0           B         204 E 47TH ST     60653     GRAND BOULEVARD
# 1           B  3600 N LAKE SHORE DR     60613           LAKE VIEW
# 2           A     4343 S PULASKI RD     60632      ARCHER HEIGHTS
# 3           A     4700 S KEDZIE AVE     60632       BRIGHTON PARK
# 4           B   5659 W DIVERSEY AVE     60639      BELMONT CRAGIN
#
#    COMMUNITY AREA  WARD  CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE
# 0              38     3   17031381500  1.703140e+14  41.809424 -87.620952
# 1               6    46   17031060900  1.703110e+14  41.948684 -87.643650
# 2              57    14   17031570100  1.703160e+14  41.813914 -87.723665
# 3              58    14   17031842800  1.703180e+14  41.808047 -87.704119
# 4              19    30   17031190602  1.703120e+14  41.931135 -87.768612

# %% [markdown]
# Import the basemap package and fix the bug
#
# Please change the path of 'PROJ_LIB' to anaconda folder in your computer (you may copy this part from [Lab3_part2](http://localhost:8888/notebooks/Documents/UH_work/Teaching/GEOG389/git/Jupyter/Lab3_part2.ipynb))

# %% [markdown]
# Plot the store locations in a basemap

# %%
f, ax1 = plt.subplots(1, figsize=(15, 10))

map = Basemap(llcrnrlon=-87.956941,llcrnrlat=41.630464,urcrnrlon=-87.429476,urcrnrlat=42.039636, epsg=4269, ax=ax1)
#https://www.bdmweather.com/2018/04/python-m-arcgisimage-basemap-options/

map.arcgisimage(service='ESRI_StreetMap_World_2D', xpixels = 2000, verbose= True)

#ct.plot(color='white', edgecolor='black', linewidth = .1,ax=ax1)
ax1.plot(df['LONGITUDE'],df['LATITUDE'],'b*',markersize=5)


plt.show()
# Out:
# http://server.arcgisonline.com/ArcGIS/rest/services/ESRI_StreetMap_World_2D/MapServer/export?bbox=-87.956941,41.630464,-87.429476,42.039636&bboxSR=4269&imageSR=4269&size=2000,1551&dpi=96&format=png32&transparent=true&f=image

# %% [markdown]
# Extract stores within a rectangle. The coordinates of the bottom-left corner are [-87.7449, 41.7220] and the coordinates of the top-right corner are [-87.6247,41.8727]

# %%
df = df[(df['LATITUDE']> 41.721999) &(df['LATITUDE']<41.872709)]
df = df[(df['LONGITUDE']> -87.744988) &(df['LONGITUDE']<-87.624699)]

# %% [markdown]
# ## 1. Convert coordinate system

# %%
from pyproj import Proj

# %% [markdown]
# Create the projected coordinate system of UTM zone 16T (the zone where Chicago is in)
#
# Click [here](https://jswhit.github.io/pyproj/) for information of other projections.
#
# ![alt_text](images/fig12.jpg)

# %%
# create an projection object for UTM 16T zone.
myProj =  Proj("+proj=utm +zone = 16T, +north +ellps=GRS80 +datum=NAD83 +units=m +no_defs")

# %% [markdown]
# Convert the lat,lon of the points to northing and easting.
#
# Please write code to extract the columns of latitude and longitude into two list

# %%
lat = 
lon =

# %%
easting, northing = myProj(lat, lon)

# %% [markdown]
# Convert the lists of easting and northing coordinates into a data frame, because PointPattern only accept dataframe as the input
#
# Note: when manipulating data in Python, you often needs do data conversion among different types to fit the input of different functions.

# %%
df = pd.DataFrame({'e': easting, 'n': northing})

# %%
pp = PointPattern(df)

# %% [markdown]
# Print the indices of the nearest neighbor of each point and the distance to the nearest neighbor

# %%
pp.knn()
#pp.knn(2)
# Out:
# (array([[  9],
#         [  6],
#         [ 50],
#         [  8],
#         [ 57],
#         [113],
#         [ 26],
#         [ 51],
#         [  3],
#         [  0],
#         [139],
#         [ 58],
#         [ 27],
#         [ 46],
#         [ 64],
#         [123],
#         [105],
#         [ 37],
#         [ 59],
#         [ 87],
#         [ 63],
#         [ 32],
#         [101],
#         [ 24],
#         [ 23],
#         [102],
#         [  6],
#         [ 12],
#         [ 76],
#         [ 65],
#         [ 68],
#         [102],
#         [ 21],
#         [ 80],
#         [116],
#         [115],
#         [104],
#         [ 17],
#         [143],
#         [ 18],
#         [107],
#         [ 76],
#         [107],
#         [101],
#         [ 70],
#         [150],
#         [ 13],
#         [ 67],
#         [  5],
#         [124],
#         [  2],
#         [  7],
#         [100],
#         [ 91],
#         [ 79],
#         [ 29],
#         [128],
#         [  4],
#         [119],
#         [ 18],
#         [137],
#         [ 15],
#         [ 11],
#         [ 20],
#         [ 14],
#         [ 29],
#         [104],
#         [ 47],
#         [ 30],
#         [ 85],
#         [ 39],
#         [115],
#         [129],
#         [ 50],
#         [ 84],
#         [ 79],
#         [ 28],
#         [ 53],
#         [125],
#         [ 54],
#         [ 33],
#         [118],
#         [ 60],
#         [ 54],
#         [ 74],
#         [ 80],
#         [  3],
#         [ 19],
#         [137],
#         [ 14],
#         [ 43],
#         [ 53],
#         [ 58],
#         [112],
#         [114],
#         [150],
#         [ 99],
#         [136],
#         [126],
#         [106],
#         [ 52],
#         [148],
#         [ 31],
#         [108],
#         [144],
#         [106],
#         [ 99],
#         [ 42],
#         [103],
#         [ 88],
#         [131],
#         [ 78],
#         [ 93],
#         [  5],
#         [ 94],
#         [ 35],
#         [ 34],
#         [ 55],
#         [ 81],
#         [ 58],
#         [ 21],
#         [ 15],
#         [ 32],
#         [147],
#         [121],
#         [ 78],
#         [100],
#         [135],
#         [121],
#         [ 79],
#         [ 43],
#         [125],
#         [133],
#         [132],
#         [146],
#         [127],
#         [ 97],
#         [ 88],
#         [144],
#         [ 36],
#         [118],
#         [133],
#         [ 35],
#         [ 38],
#         [104],
#         [ 62],
#         [134],
#         [123],
#         [148],
#         [146],
#         [ 45]]), array([[ 407.23518013],
#         [ 760.85892667],
#         [ 580.64944445],
#         [1007.24075167],
#         [ 538.84678791],
#         [ 414.01832827],
#         [ 694.3532742 ],
#         [ 541.08354891],
#         [1007.24075167],
#         [ 407.23518013],
#         [4731.13423262],
#         [1121.68160038],
#         [ 135.80015691],
#         [1059.56605323],
#         [ 149.64284991],
#         [ 215.39630552],
#         [1401.25679589],
#         [1247.08414547],
#         [ 216.8879257 ],
#         [ 909.94741794],
#         [ 779.32025236],
#         [ 509.59650094],
#         [ 573.78691293],
#         [1304.02986825],
#         [1304.02986825],
#         [1008.32570831],
#         [ 694.3532742 ],
#         [ 135.80015691],
#         [ 173.08221403],
#         [ 296.74043752],
#         [1026.52197853],
#         [ 796.03265825],
#         [ 509.59650094],
#         [ 300.69681872],
#         [ 549.77113199],
#         [ 833.32848086],
#         [1392.96944901],
#         [1247.08414547],
#         [ 721.68773393],
#         [ 754.71598261],
#         [ 881.43725031],
#         [ 545.01226958],
#         [ 119.44585703],
#         [ 403.68559477],
#         [1664.50219904],
#         [ 368.33573035],
#         [1059.56605323],
#         [  82.98092265],
#         [ 837.9367085 ],
#         [ 967.85194491],
#         [ 580.64944445],
#         [ 541.08354891],
#         [1182.94081068],
#         [ 300.81576444],
#         [ 472.48204241],
#         [ 648.83308492],
#         [1241.00691421],
#         [ 538.84678791],
#         [ 858.45843681],
#         [ 216.8879257 ],
#         [1263.5512915 ],
#         [ 411.02847238],
#         [1238.62202305],
#         [ 779.32025236],
#         [ 149.64284991],
#         [ 296.74043752],
#         [2180.86082988],
#         [  82.98092265],
#         [1026.52197853],
#         [1431.96478386],
#         [ 946.50115707],
#         [1225.15864418],
#         [1297.45727092],
#         [ 951.88541292],
#         [ 528.82215234],
#         [ 594.54318667],
#         [ 173.08221403],
#         [ 620.86697812],
#         [ 373.43407576],
#         [ 472.48204241],
#         [ 300.69681872],
#         [1261.04433356],
#         [1564.15994421],
#         [ 954.11090066],
#         [ 528.82215234],
#         [ 612.27354885],
#         [1173.35023979],
#         [ 909.94741794],
#         [ 353.12978443],
#         [ 752.11572954],
#         [ 879.80480578],
#         [ 300.81576444],
#         [ 899.87565347],
#         [ 429.68541545],
#         [ 415.9681702 ],
#         [ 570.67171018],
#         [ 606.15935265],
#         [ 298.03968441],
#         [1930.16349202],
#         [ 100.5830813 ],
#         [1182.94081068],
#         [   0.        ],
#         [ 796.03265825],
#         [ 601.50114709],
#         [ 110.28938716],
#         [ 570.04144803],
#         [ 100.5830813 ],
#         [ 119.44585703],
#         [ 601.50114709],
#         [ 901.48441659],
#         [ 576.73154511],
#         [ 415.66460156],
#         [ 429.68541545],
#         [ 414.01832827],
#         [ 415.9681702 ],
#         [ 833.32848086],
#         [ 549.77113199],
#         [ 927.27456565],
#         [1261.04433356],
#         [ 858.45843681],
#         [ 600.72197176],
#         [ 409.19870876],
#         [ 705.76846713],
#         [  22.4988983 ],
#         [ 443.15323796],
#         [ 373.43407576],
#         [1326.33548065],
#         [ 250.44403431],
#         [ 481.37592758],
#         [ 782.65252334],
#         [ 910.51884031],
#         [ 432.95741653],
#         [ 455.62576939],
#         [ 455.62576939],
#         [ 111.99026049],
#         [ 250.44403431],
#         [ 298.03968441],
#         [ 353.12978443],
#         [1287.39875131],
#         [4161.06736426],
#         [1380.71587736],
#         [1345.72753077],
#         [1439.27512253],
#         [ 721.68773393],
#         [ 110.28938716],
#         [1775.2572799 ],
#         [ 111.99026049],
#         [  22.4988983 ],
#         [   0.        ],
#         [1185.60290578],
#         [ 368.33573035]]))

# %% [markdown]
# Calculate the NNDs

# %%
pp.nnd
# Out:
# array([[ 407.23518013],
#        [ 760.85892667],
#        [ 580.64944445],
#        [1007.24075167],
#        [ 538.84678791],
#        [ 414.01832827],
#        [ 694.3532742 ],
#        [ 541.08354891],
#        [1007.24075167],
#        [ 407.23518013],
#        [4731.13423262],
#        [1121.68160038],
#        [ 135.80015691],
#        [1059.56605323],
#        [ 149.64284991],
#        [ 215.39630552],
#        [1401.25679589],
#        [1247.08414547],
#        [ 216.8879257 ],
#        [ 909.94741794],
#        [ 779.32025236],
#        [ 509.59650094],
#        [ 573.78691293],
#        [1304.02986825],
#        [1304.02986825],
#        [1008.32570831],
#        [ 694.3532742 ],
#        [ 135.80015691],
#        [ 173.08221403],
#        [ 296.74043752],
#        [1026.52197853],
#        [ 796.03265825],
#        [ 509.59650094],
#        [ 300.69681872],
#        [ 549.77113199],
#        [ 833.32848086],
#        [1392.96944901],
#        [1247.08414547],
#        [ 721.68773393],
#        [ 754.71598261],
#        [ 881.43725031],
#        [ 545.01226958],
#        [ 119.44585703],
#        [ 403.68559477],
#        [1664.50219904],
#        [ 368.33573035],
#        [1059.56605323],
#        [  82.98092265],
#        [ 837.9367085 ],
#        [ 967.85194491],
#        [ 580.64944445],
#        [ 541.08354891],
#        [1182.94081068],
#        [ 300.81576444],
#        [ 472.48204241],
#        [ 648.83308492],
#        [1241.00691421],
#        [ 538.84678791],
#        [ 858.45843681],
#        [ 216.8879257 ],
#        [1263.5512915 ],
#        [ 411.02847238],
#        [1238.62202305],
#        [ 779.32025236],
#        [ 149.64284991],
#        [ 296.74043752],
#        [2180.86082988],
#        [  82.98092265],
#        [1026.52197853],
#        [1431.96478386],
#        [ 946.50115707],
#        [1225.15864418],
#        [1297.45727092],
#        [ 951.88541292],
#        [ 528.82215234],
#        [ 594.54318667],
#        [ 173.08221403],
#        [ 620.86697812],
#        [ 373.43407576],
#        [ 472.48204241],
#        [ 300.69681872],
#        [1261.04433356],
#        [1564.15994421],
#        [ 954.11090066],
#        [ 528.82215234],
#        [ 612.27354885],
#        [1173.35023979],
#        [ 909.94741794],
#        [ 353.12978443],
#        [ 752.11572954],
#        [ 879.80480578],
#        [ 300.81576444],
#        [ 899.87565347],
#        [ 429.68541545],
#        [ 415.9681702 ],
#        [ 570.67171018],
#        [ 606.15935265],
#        [ 298.03968441],
#        [1930.16349202],
#        [ 100.5830813 ],
#        [1182.94081068],
#        [   0.        ],
#        [ 796.03265825],
#        [ 601.50114709],
#        [ 110.28938716],
#        [ 570.04144803],
#        [ 100.5830813 ],
#        [ 119.44585703],
#        [ 601.50114709],
#        [ 901.48441659],
#        [ 576.73154511],
#        [ 415.66460156],
#        [ 429.68541545],
#        [ 414.01832827],
#        [ 415.9681702 ],
#        [ 833.32848086],
#        [ 549.77113199],
#        [ 927.27456565],
#        [1261.04433356],
#        [ 858.45843681],
#        [ 600.72197176],
#        [ 409.19870876],
#        [ 705.76846713],
#        [  22.4988983 ],
#        [ 443.15323796],
#        [ 373.43407576],
#        [1326.33548065],
#        [ 250.44403431],
#        [ 481.37592758],
#        [ 782.65252334],
#        [ 910.51884031],
#        [ 432.95741653],
#        [ 455.62576939],
#        [ 455.62576939],
#        [ 111.99026049],
#        [ 250.44403431],
#        [ 298.03968441],
#        [ 353.12978443],
#        [1287.39875131],
#        [4161.06736426],
#        [1380.71587736],
#        [1345.72753077],
#        [1439.27512253],
#        [ 721.68773393],
#        [ 110.28938716],
#        [1775.2572799 ],
#        [ 111.99026049],
#        [  22.4988983 ],
#        [   0.        ],
#        [1185.60290578],
#        [ 368.33573035]])

# %% [markdown]
# Calculate the NNDs

# %% [markdown]
# Mean NND

# %%
pp.mean_nnd
# Out:
# 735.7470244241224

# %% [markdown]
# Maximum nearest neighbor distance

# %%
pp.max_nnd
# Out:
# 4731.134232615514

# %% [markdown]
# Minimum nearest neighbor distance

# %%
pp.nnd.mean()
# Out:
# 735.7470244241224

# %% [markdown]
# Plot the points

# %%
pp.plot()
#plt.axis('equal')

# %% [markdown]
# ## 3. Statistic Test of Nearest Neighbor Distance

# %% [markdown]
# Simulate 999 randomly distributed point sets in the window of the store locations.
#
# Note: this process may take a while to run

# %%
csr_process = PoissonPointProcess(pp.window, pp.n, 999, asPP=True)

# %% [markdown]
# Get the random point sets.

# %%
csr_real = csr_process.realizations

# %% [markdown]
# Plot points in one of the set (realization).

# %%
csr_real[6].plot()

# %%
csr_real[4].mean_nnd
# Out:
# 833.9286836911905

# %% [markdown]
# Use a for loop to get the mean NND of the 999 random sets

# %%
csr_mean_ls=[]
for i in range(0,len(csr_real)):
    csr_mean_ls.append(csr_real[i].mean_nnd)

# %% [markdown]
# Get the mean of the mean NNDs

# %%
np.mean(csr_mean_ls)
# Out:
# 535.9916237495441

# %%
pp.mean_nnd
# Out:
# 494.1399704931842

# %% [markdown]
# Get the mean and standard deviation of NNDs of the 999 random sets.

# %%
csr_mean = np.mean(csr_mean_ls)
csr_std = np.std(csr_mean_ls)

# %%
pd.DataFrame(csr_mean_ls).hist(bins=50)

plt.axvline([csr_mean-2*csr_std], color='b')
plt.axvline([csr_mean-1*csr_std], color='b')
plt.axvline([csr_mean], color='b')
plt.axvline([csr_mean+csr_std], color='b')
plt.axvline([csr_mean+2*csr_std], color='b')

plt.axvline([pp.mean_nnd], color='r')

# %%
from scipy import stats
stats.ttest_1samp(csr_mean_ls,pp.mean_nnd)
# Out:
# Ttest_1sampResult(statistic=55.870662315172325, pvalue=1.657571995907845e-309)

# %%
z = (pp.mean_nnd - np.mean(csr_mean_ls))/np.std(csr_mean_ls)
z
# Out:
# -1.768554913056705

# %%
stats.norm.cdf(z)
# Out:
# 0.03848409028404088

# %% [markdown]
# Refer to the following illustration, how would you interpret the result?

# %% [markdown]
# ![](images/fig11.jpg)

# %% [markdown]
# ### K-function

# %%
realizations = PoissonPointProcess(pp.window, pp.n, 100, asPP=True) # simulate CSR 100 times

# %%
type(realization)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-659-b6a36455565d> in <module>
# ----> 1 type(realization)
#
# NameError: name 'realization' is not defined

# %%
kenv = Kenv(pp, intervals=20, realizations=realizations)
kenv.plot()
